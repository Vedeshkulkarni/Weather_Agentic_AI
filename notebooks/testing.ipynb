# %%
from langchain_core.tools import Tool, tool
import requests
import os
from dotenv import load_dotenv
load_dotenv()
weather_api_key = os.getenv("weather_api_key")
@tool
def get_weather(location: str) -> str:
    """get current weather and temperature for a given city or location"""
    url = f"http://api.openweathermap.org/data/2.5/weather?q={location}&appid={weather_api_key}&units=metric"
    response = requests.get(url)
    data = response.json()
    if response.status_code == 200:
        temperature = data["main"]["temp"]
        humidity = data["main"]["humidity"]         
        wind_speed = data["wind"]["speed"]          
        description = data["weather"][0]["description"]  
        main_weather = data["weather"][0]["main"]       
        feels_like = data["main"]["feels_like"]    
        return (
            f"weather in {location} is {main_weather} ({description}) with temperature{temperature}°C\n"
            f"it feels like {feels_like}°C\n"
            f"humidity={humidity}%\n"
            f"wind speed={wind_speed} m/s\n"
        )
    else:
        return "Sorry, I couldn't fetch the weather information for that location."

# %%
from langchain_core.tools import Tool, tool
import requests
import os
from dotenv import load_dotenv
load_dotenv()
weather_api_key = os.getenv("weather_api_key")
@tool
def get_weather(location: str) -> str:
    """get current weather and temperature for a given city or location"""
    url = f"http://api.openweathermap.org/data/2.5/weather?q={location}&appid={weather_api_key}&units=metric"
    response = requests.get(url)
    data = response.json()
    if response.status_code == 200:
        temperature = data["main"]["temp"]
        humidity = data["main"]["humidity"]         
        wind_speed = data["wind"]["speed"]          
        description = data["weather"][0]["description"]  
        main_weather = data["weather"][0]["main"]       
        feels_like = data["main"]["feels_like"]    
        return (
            f"weather in {location} is {main_weather} ({description}) with temperature{temperature}°C\n"
            f"it feels like {feels_like}°C\n"
            f"humidity={humidity}%\n"
            f"wind speed={wind_speed} m/s\n"
        )
    else:
        return "Sorry, I couldn't fetch the weather information for that location."

# %%
os.chdir(r"D:\vedes\Documents\PROJECTS\Weather_Agentic_AI")
from src.agent import ask_agent
if __name__ == "__main__":
    while True:
        question = input("You: ")

        if question.lower() in ["exit", "quit"]:
            print("Goodbye!")
            break

        answer = ask_agent(question)
        print("Agent: ", answer)
# Out:
# Goodbye!

# %%
import os
from dotenv import load_dotenv
from openai import OpenAI

load_dotenv()

client = OpenAI(
    api_key=os.getenv("OPENROUTER_API_KEY"),
    base_url="https://openrouter.ai/api/v1",
)

response = client.chat.completions.create(
    model="openrouter/auto",
    messages=[
        {
            "role": "user",
            "content": "Hello! Tell me about yourself."
        }
    ]
)

print(response.choices[0].message.content)
# Out:
# Hi! I’m ChatGPT, a conversational AI built by OpenAI. I’m here to help with a wide range of tasks, including:
#
# - Explaining ideas and answering questions
# - Writing, editing, and polishing text (essays, emails, resumes, stories)
# - Brainstorming and planning (projects, schedules, itineraries)
# - Coding help, debugging, and tech explanations
# - Translating and summarizing content
# - Solving math and data-oriented problems
# - Research-style questions (based on my training data up to 2024-06)
#
# I can also analyze images you share: I can describe what’s in the image, identify objects, extract text, and answer questions about it.
#
# A few practical notes:
# - I don’t have real-time web access unless you use a tool that provides it; my knowledge is current up to 2024-06.
# - I don’t remember personal details from one chat to the next unless you tell me to store them for this conversation.
# - I aim to be helpful and safe, and I’ll avoid giving dangerous or inappropriate instructions.
#
# Would you like to tell me your goal or task, and I’ll tailor my help? If you’re unsure, I can suggest a starting task—editing a paragraph, planning a project, or debugging some code, for example.
